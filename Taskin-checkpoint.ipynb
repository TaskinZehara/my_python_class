# %%
a=10
print(a)
# Out:
# 10

# %%
whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          int     10

# %%
in=2
# Out:
#   Cell In[6], line 1
#     in=2
#     ^
# SyntaxError: invalid syntax

# %%
4%5
# Out:
# 4

# %%
x = 125 
y=13
x//=y
print(x)
# Out:
# 9

# %% [markdown]
# ## IF

# %%
a =-9
if a > 0:
    print("positive")
    #no output bcz a<0

# %% [markdown]
# ## IF ELSE

# %%
a = -9
if a>0 :
    print("positive")
else:
    print("non positive")
# Out:
# non positive

# %%
a = int(input("enter num to check:"))
if(a>0):
    print("positive")
elif a==0:
    print("zero")
else:
    print("non positive")
# Out:
# enter num to check: 0
# zero

# %% [markdown]
# ##   QUE : TAKE INPUT NUM AND CHECK DIVISIBLE BY 5 AND 7

# %%
a = int(input("enter num : "))
if a%5==0 and a%7==0:
    print("diisible by 5 and 7")
else:
    print("not divisable")
# Out:
# enter num :  70
# diisible by 5 and 7

# %% [markdown]
# ## RANGE FUNCTION
# `range(start, stop, step)`
# - start: Where to begin (defaults to 0).
# - stop: Where to end (generates numbers up to, but not including, this value).
# - step: How much to increment or decrement by (defaults to 1).

# %%
range?
# Out:
# Init signature: range(self, /, *args, **kwargs)
# Docstring:
# range(stop) -> range object
# range(start, stop[, step]) -> range object
#
# Return an object that produces a sequence of integers from start (inclusive)
# to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
# start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
# These are exactly the valid indices for a list of 4 elements.
# When step is given, it specifies the increment (or decrement).
# Type:           type
# Subclasses:

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(2,5))
# Out:
# [2, 3, 4]

# %%
list(range(2,-5))
# by default step is 1 so -5 in not include in this range lsit
# Out:
# []

# %%
list(range(0,10,2))
# Out:
# [0, 2, 4, 6, 8]

# %%
list(range(10,0,-2))
# Out:
# [10, 8, 6, 4, 2]

# %% [markdown]
# ## WHILE LOOP

# %%
a= 5 # limit
count = 0 #starting
while count<a:
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## nested loop

# %%
for i in range(5):
    print("python",end="")
    print("i at the end of loop is",i )
# Out:
# pythoni at the end of loop is 0
# pythoni at the end of loop is 1
# pythoni at the end of loop is 2
# pythoni at the end of loop is 3
# pythoni at the end of loop is 4

# %%
for i in range(10,3,-2):
    print(i,end="")

for i in range(10,3,-2):
    print(i,end=" ")
# Out:
# 1086410 8 6 4

# %%
for i in range(65,100):
    print(i,end=" ")
    print(i,chr(i))
# Out:
# 65 65 A
# 66 66 B
# 67 67 C
# 68 68 D
# 69 69 E
# 70 70 F
# 71 71 G
# 72 72 H
# 73 73 I
# 74 74 J
# 75 75 K
# 76 76 L
# 77 77 M
# 78 78 N
# 79 79 O
# 80 80 P
# 81 81 Q
# 82 82 R
# 83 83 S
# 84 84 T
# 85 85 U
# 86 86 V
# 87 87 W
# 88 88 X
# 89 89 Y
# 90 90 Z
# 91 91 [
# 92 92 \
# 93 93 ]
# 94 94 ^
# 95 95 _
# 96 96 `
# 97 97 a
# 98 98 b
# 99 99 c

# %%
for i in "python":
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in "python":
    print(i,end="")
# Out:
# python

# %%
for i in "python":
    print("hello",end=" ")
# Out:
# hello hello hello hello hello hello

# %% [markdown]
# ## WAY TO PYTHON PROGRAMM TO CREATE A MULTIPLICATION TABLE OF 13*1 =13

# %%
for i in range(10):
    print("13 * ",i+1,"=",(i+1)*13)
# Out:
# 13 *  1 = 13
# 13 *  2 = 26
# 13 *  3 = 39
# 13 *  4 = 52
# 13 *  5 = 65
# 13 *  6 = 78
# 13 *  7 = 91
# 13 *  8 = 104
# 13 *  9 = 117
# 13 *  10 = 130

# %%
for i in range(1,11):
    print("13 * ",i,"=",13*i)
# Out:
# 13 *  1 = 13
# 13 *  2 = 26
# 13 *  3 = 39
# 13 *  4 = 52
# 13 *  5 = 65
# 13 *  6 = 78
# 13 *  7 = 91
# 13 *  8 = 104
# 13 *  9 = 117
# 13 *  10 = 130

# %%
a =int(input())
if a%4==0 and a%100!=0 and a%400==0:
    print("leap year")
else:
    print("non leap year")
# Out:
#  2022
# non leap year

# %%
a=int(input())
print("leap year "if  a%4==0 and a%100!=0 or a%400==0 else "non leap year"  )
# Out:
#  2028
# leap year

# %%
num = input()
print(num,+num+num,+num+num+num,+num+num+num+num)
# Out:
#  43
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 num = input()
# ----> 2 print(num,+num+num,+num+num+num,+num+num+num+num)
#
# TypeError: bad operand type for unary +: 'str'

# %%
num = input()
print(num,num+num,num+num+num,num+num+num+num)
# Out:
#  43
# 43 4343 434343 43434343
